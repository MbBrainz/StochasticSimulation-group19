# %%
from sampling_functions import generate_pureRandomSample, generate_latinHyperCube, generate_Orthogonal, generate_sobol

re_lim=(-2,1) 
im_lim=(-1,1)

# %%
generate_pureRandomSample(9, show_plot=True)
# Out:
# array([-0.1087885 +0.9147462j , -1.59178328-0.45095352j,
#        -0.24212912-0.58904344j,  0.21182821-0.54339168j,
#        -1.38816672-0.61435878j, -0.7787691 -0.76300753j,
#        -1.84722801+0.88041175j,  0.23699555+0.33030118j,
#         0.64584653-0.94376119j])

# %%
generate_latinHyperCube(9, show_plot=True)
# Out:
# array([-1.99843174+0.30666451j, -1.40482381-1.10531867j,
#        -1.24705606-0.3140736j , -0.74826781-0.6957181j ,
#        -0.42166062+0.83357064j, -0.09016712+0.58396454j,
#         0.18118787-0.47107632j,  0.53838387+1.00140021j,
#         0.67746352+0.00198689j])

# %%
generate_Orthogonal(9, show_plot=True)
# Out:
# array([-1.96554894-1.20265176j, -1.22541027+0.35009524j,
#        -1.43976182+0.5281208j , -0.46129122-0.71046995j,
#        -0.70635598-0.18787698j, -0.29860352+0.70613501j,
#         0.68768275-0.5939515j ,  0.62564629+0.08011867j,
#         0.16149124+0.99138078j])

# %%
gener
