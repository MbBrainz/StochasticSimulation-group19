# %%
import numpy as np
import math
from random import seed
from random import random
from numba import jit


from functions import read_tsp_file
from functions import comp_shortest_path

# %% [markdown]
# ## Markov chain length - 10,000

# %%
T_start = 1000
T_end = 0.005
cooling_factor_arr = [0.5,0.6,0.7,0.8,0.9,0.98,0.99]
nMarkov = 10000
num_simulations = 10

coords = read_tsp_file("TSP-Configurations/a280.tsp")
dataset = "a280"

for cooling_factor in cooling_factor_arr:
    print("cooling factor : ",cooling_factor)
    print("\n")
    for run in range(num_simulations):
        print("Simulation run :",run)
        itr, min_cost, optimal_list_cities,local_minima_arr = comp_shortest_path(T_start, T_end, cooling_factor, nMarkov, coords, dataset=dataset, save_data=True)
        print("Minimum route Cost : ",min_cost)
    print("\n")
# Out:
# cooling factor :  0.5
#
#
# Simulation run : 0
# Minimum route Cost :  3034.438875075891
# Simulation run : 1
# Minimum route Cost :  3090.1875359885767
# Simulation run : 2
# Minimum route Cost :  3123.9088564524404
# Simulation run : 3
# Minimum route Cost :  3094.5391687317474
# Simulation run : 4
# Minimum route Cost :  3075.473661108477
# Simulation run : 5
# Minimum route Cost :  3142.3757203778136
# Simulation run : 6
# Minimum route Cost :  3148.9261407671543
# Simulation run : 7
# Minimum route Cost :  3149.372155945167
# Simulation run : 8
# Minimum route Cost :  3145.730488229444
# Simulation run : 9
# Minimum route Cost :  2936.377943929884
#
#
# cooling factor :  0.6
#
#
# Simulation run : 0
# Minimum route Cost :  2975.8891757970364
# Simulation run : 1
# Minimum route Cost :  3061.123139307801
# Simulation run : 2
# Minimum route Cost :  2925.1030352450225
# Simulation run : 3
# Minimum route Cost :  3107.9939848623076
# Simulation run : 4
# Minimum route Cost :  3037.4691376403184
# Simulation run : 5
# Minimum route Cost :  3074.238451003814
# Simulation run : 6
# Minimum route Cost :  2949.8272523060577
# Simulation run : 7
# Minimum route Cost :  3005.2756451682535
# Simulation run : 8
# Minimum route Cost :  3047.2637865347883
# Simulation run : 9
# Minimum route Cost :  2951.031733746709
#
#
# cooling factor :  0.7
#
#
# Simulation run : 0
# Minimum route Cost :  2897.293125031467
# Simulation run : 1
# Minimum route Cost :  3087.945524510885
# Simulation run : 2
# Minimum route Cost :  2882.4280659738656
# Simulation run : 3
# Minimum route Cost :  3045.83881204291
# Simulation run : 4
# Minimum route Cost :  2955.2902532276908
# Simulation run : 5
# Minimum route Cost :  2949.7694580217503
# Simulation run : 6
# Minimum route Cost :  2935.9779883170268
# Simulation run : 7
# Minimum route Cost :  3000.460411579561
# Simulation run : 8
# Minimum route Cost :  2891.058427533159
# Simulation run : 9
# Minimum route Cost :  3002.426199079437
#
#
# cooling factor :  0.8
#
#
# Simulation run : 0
# Minimum route Cost :  2918.115752623946
# Simulation run : 1
# Minimum route Cost :  2919.9866594255236
# Simulation run : 2
# Minimum route Cost :  3016.948695083134
# Simulation run : 3
# Minimum route Cost :  2886.917449083941
# Simulation run : 4
# Minimum route Cost :  2876.0000992004543
# Simulation run : 5
# Minimum route Cost :  2839.7132747897067
# Simulation run : 6
# Minimum route Cost :  2849.8842295494474
# Simulation run : 7
# Minimum route Cost :  2842.7007454458803
# Simulation run : 8
# Minimum route Cost :  2810.389630792156
# Simulation run : 9
# Minimum route Cost :  2839.124421377744
#
#
# cooling factor :  0.9
#
#
# Simulation run : 0
# Minimum route Cost :  2879.420480537823
# Simulation run : 1
# Minimum route Cost :  2821.058074536524
# Simulation run : 2
# Minimum route Cost :  2879.6797067730313
# Simulation run : 3
# Minimum route Cost :  2774.614138958259
# Simulation run : 4
# Minimum route Cost :  2871.1753463443833
# Simulation run : 5
# Minimum route Cost :  2753.5812284919243
# Simulation run : 6
# Minimum route Cost :  2835.8550043658483
# Simulation run : 7
# Minimum route Cost :  2843.9479380941502
# Simulation run : 8
# Minimum route Cost :  2789.520763814041
# Simulation run : 9
# Minimum route Cost :  2865.4874262584162
#
#
# cooling factor :  0.98
#
#
# Simulation run : 0
# Minimum route Cost :  2737.0336352245226
# Simulation run : 1
# Minimum route Cost :  2756.166675812751
# Simulation run : 2
# Minimum route Cost :  2685.3092061141274
# Simulation run : 3
# Minimum route Cost :  2668.0586577434624
# Simulation run : 4
# Minimum route Cost :  2717.6517681587575
# Simulation run : 5
# Minimum route Cost :  2666.9743352077085
# Simulation run : 6
# Minimum route Cost :  2695.1586119284207
# Simulation run : 7
# Minimum route Cost :  2769.1341479570333
# Simulation run : 8
# Minimum route Cost :  2694.1528509126088
# Simulation run : 9
# Minimum route Cost :  2672.0514650922496
#
#
# cooling factor :  0.99
#
#
# Simulation run : 0
# Minimum route Cost :  2657.510620877273
# Simulation run : 1
# Minimum route Cost :  2742.506871286286
# Simulation run : 2
# Minimum route Cost :  2629.9962450669223
# Simulation run : 3
# Minimum route Cost :  2636.1408775237646
# Simulation run : 4
# Minimum route Cost :  2593.1506138860645
# Simulation run : 5
# Minimum route Cost :  2702.774796344506
# Simulation run : 6
# Minimum route Cost :  2672.6044072215172
# Simulation run : 7
# Minimum route Cost :  2738.98741107395
# Simulation run : 8
# Minimum route Cost :  2714.071188942244
# Simulation run : 9
# Minimum route Cost :  2707.0318010168794

# %% [markdown]
# ## Markov chain length = 5000

# %%
T_start = 1000
T_end = 0.005
cooling_factor_arr = [0.5,0.6,0.7,0.8,0.9,0.98,0.99]
nMarkov = 5000
num_simulations = 10

coords = read_tsp_file("TSP-Configurations/a280.tsp")
dataset = "a280"

for cooling_factor in cooling_factor_arr:
    print("cooling factor : ",cooling_factor)
    print("\n")
    for run in range(num_simulations):
        print("Simulation run :",run)
        itr, min_cost, optimal_list_cities,local_minima_arr = comp_shortest_path(T_start, T_end, cooling_factor, nMarkov, coords, dataset=dataset, save_data=True)
        print("Minimum route Cost : ",min_cost)
    print("\n")
# Out:
# cooling factor :  0.5
#
#
# Simulation run : 0
# Minimum route Cost :  3605.2302233190053
# Simulation run : 1
# Minimum route Cost :  3580.228112929127
# Simulation run : 2
# Minimum route Cost :  3528.256388294594
# Simulation run : 3
# Minimum route Cost :  3575.535646740614
# Simulation run : 4
# Minimum route Cost :  3548.8111872804675
# Simulation run : 5
# Minimum route Cost :  3593.0997072560367
# Simulation run : 6
# Minimum route Cost :  3438.728048695524
# Simulation run : 7
# Minimum route Cost :  3469.2795658609075
# Simulation run : 8
# Minimum route Cost :  3659.0049690352903
# Simulation run : 9
# Minimum route Cost :  3677.025592707992
#
#
# cooling factor :  0.6
#
#
# Simulation run : 0
# Minimum route Cost :  3386.595101527929
# Simulation run : 1
# Minimum route Cost :  3364.55924917227
# Simulation run : 2
# Minimum route Cost :  3242.756100935956
# Simulation run : 3
# Minimum route Cost :  3236.688388215468
# Simulation run : 4
# Minimum route Cost :  3226.8570621763847
# Simulation run : 5
# Minimum route Cost :  3236.8184737802007
# Simulation run : 6
# Minimum route Cost :  3396.701218749576
# Simulation run : 7
# Minimum route Cost :  3418.604982390538
# Simulation run : 8
# Minimum route Cost :  3415.0067625680676
# Simulation run : 9
# Minimum route Cost :  3373.8353394421165
#
#
# cooling factor :  0.7
#
#
# Simulation run : 0
# Minimum route Cost :  3113.6942114946232
# Simulation run : 1
# Minimum route Cost :  3168.750964843358
# Simulation run : 2
# Minimum route Cost :  3140.9723545902643
# Simulation run : 3
# Minimum route Cost :  3054.2002699492523
# Simulation run : 4
# Minimum route Cost :  3215.3372259663724
# Simulation run : 5
# Minimum route Cost :  3189.9573806015414
# Simulation run : 6
# Minimum route Cost :  3109.167058328472
# Simulation run : 7
# Minimum route Cost :  3195.0740379858194
# Simulation run : 8
# Minimum route Cost :  3036.019814123348
# Simulation run : 9
# Minimum route Cost :  3054.3469416083567
#
#
# cooling factor :  0.8
#
#
# Simulation run : 0
# Minimum route Cost :  2962.0663272218035
# Simulation run : 1
# Minimum route Cost :  3060.4423994615054
# Simulation run : 2
# Minimum route Cost :  3033.4530036233405
# Simulation run : 3
# Minimum route Cost :  2998.0446420391117
# Simulation run : 4
# Minimum route Cost :  3018.434675161978
# Simulation run : 5
# Minimum route Cost :  2978.2847933636426
# Simulation run : 6
# Minimum route Cost :  2928.383286329423
# Simulation run : 7
# Minimum route Cost :  2939.148402162058
# Simulation run : 8
# Minimum route Cost :  3024.91765604053
# Simulation run : 9
# Minimum route Cost :  3064.725687381739
#
#
# cooling factor :  0.9
#
#
# Simulation run : 0
# Minimum route Cost :  2965.6400355123956
# Simulation run : 1
# Minimum route Cost :  2893.917279130365
# Simulation run : 2
# Minimum route Cost :  2965.4408345622137
# Simulation run : 3
# Minimum route Cost :  2872.3761479617015
# Simulation run : 4
# Minimum route Cost :  2935.8918441433007
# Simulation run : 5
# Minimum route Cost :  2777.189347356877
# Simulation run : 6
# Minimum route Cost :  2874.9879151325795
# Simulation run : 7
# Minimum route Cost :  2987.1786268035085
# Simulation run : 8
# Minimum route Cost :  2911.322573132905
# Simulation run : 9
# Minimum route Cost :  2903.450178195475
#
#
# cooling factor :  0.98
#
#
# Simulation run : 0
# Minimum route Cost :  2791.4563752314807
# Simulation run : 1
# Minimum route Cost :  2729.732591202621
# Simulation run : 2
# Minimum route Cost :  2829.550519793234
# Simulation run : 3
# Minimum route Cost :  2753.7358822320152
# Simulation run : 4
# Minimum route Cost :  2689.1536355427606
# Simulation run : 5
# Minimum route Cost :  2707.524515143781
# Simulation run : 6
# Minimum route Cost :  2756.823329486626
# Simulation run : 7
# Minimum route Cost :  2715.7563004449557
# Simulation run : 8
# Minimum route Cost :  2757.463102715682
# Simulation run : 9
# Minimum route Cost :  2680.080273851715
#
#
# cooling factor :  0.99
#
#
# Simulation run : 0
# Minimum route Cost :  2756.106667877342
# Simulation run : 1
# Minimum route Cost :  2767.1071472552107
# Simulation run : 2
# Minimum route Cost :  2684.2164532684246
# Simulation run : 3
# Minimum route Cost :  2713.735586608062
# Simulation run : 4
# Minimum route Cost :  2687.3983001304364
# Simulation run : 5
# Minimum route Cost :  2763.7083488791927
# Simulation run : 6
# Minimum route Cost :  2716.530499398768
# Simulation run : 7
# Minimum route Cost :  2701.2016825218698
# Simulation run : 8
# Minimum route Cost :  2649.337239900301
# Simulation run : 9
# Minimum route Cost :  2751.2302872788555

# %% [markdown]
# ## Markov chain length - 13,000

# %%
T_start = 1000
T_end = 0.005
cooling_factor_arr = [0.5,0.6,0.7,0.8,0.9,0.98,0.99]
nMarkov = 13000
num_simulations = 10

coords = read_tsp_file("TSP-Configurations/a280.tsp")
dataset = "a280"

for cooling_factor in cooling_factor_arr:
    print("cooling factor : ",cooling_factor)
    print("\n")
    for run in range(num_simulations):
        print("Simulation run :",run)
        itr, min_cost, optimal_list_cities,local_minima_arr = comp_shortest_path(T_start, T_end, cooling_factor, nMarkov, coords, dataset=dataset, save_data=True)
        print("Minimum route Cost : ",min_cost)
    print("\n")
# Out:
# cooling factor :  0.5
#
#
# Simulation run : 0
# Minimum route Cost :  3006.0104506804314
# Simulation run : 1
# Minimum route Cost :  3043.94298222194
# Simulation run : 2
# Minimum route Cost :  3029.595918976112
# Simulation run : 3
# Minimum route Cost :  2965.4862019175976
# Simulation run : 4
# Minimum route Cost :  3170.4185808522907
# Simulation run : 5
# Minimum route Cost :  3129.0884927056245
# Simulation run : 6
# Minimum route Cost :  2966.654028312128
# Simulation run : 7
# Minimum route Cost :  2931.6056861149386
# Simulation run : 8
# Minimum route Cost :  3061.3045913991655
# Simulation run : 9
# Minimum route Cost :  3068.112549777641
#
#
# cooling factor :  0.6
#
#
# Simulation run : 0
# Minimum route Cost :  2915.531876787573
# Simulation run : 1
# Minimum route Cost :  2924.5222958387135
# Simulation run : 2
# Minimum route Cost :  2977.0435875106064
# Simulation run : 3
# Minimum route Cost :  2914.5483009346085
# Simulation run : 4
# Minimum route Cost :  2982.76725491203
# Simulation run : 5
# Minimum route Cost :  3022.8292700010343
# Simulation run : 6
# Minimum route Cost :  2902.533085408244
# Simulation run : 7
# Minimum route Cost :  2959.991819716666
# Simulation run : 8
# Minimum route Cost :  2950.071433114532
# Simulation run : 9
# Minimum route Cost :  2875.626557264287
#
#
# cooling factor :  0.7
#
#
# Simulation run : 0
# Minimum route Cost :  2972.3479641165923
# Simulation run : 1
# Minimum route Cost :  2931.791557100145
# Simulation run : 2
# Minimum route Cost :  2905.736119611372
# Simulation run : 3
# Minimum route Cost :  2752.200632546104
# Simulation run : 4
# Minimum route Cost :  3011.08233726502
# Simulation run : 5
# Minimum route Cost :  2969.5275541213286
# Simulation run : 6
# Minimum route Cost :  2923.815117051417
# Simulation run : 7
# Minimum route Cost :  2888.4536855180086
# Simulation run : 8
# Minimum route Cost :  2895.894621491374
# Simulation run : 9
# Minimum route Cost :  2937.7088350596523
#
#
# cooling factor :  0.8
#
#
# Simulation run : 0
# Minimum route Cost :  2925.636120073594
# Simulation run : 1
# Minimum route Cost :  2877.61850104871
# Simulation run : 2
# Minimum route Cost :  2842.7201971004633
# Simulation run : 3
# Minimum route Cost :  2889.5057544423744
# Simulation run : 4
# Minimum route Cost :  2858.029517305881
# Simulation run : 5
# Minimum route Cost :  2849.643865738409
# Simulation run : 6
# Minimum route Cost :  2861.7667357170403
# Simulation run : 7
# Minimum route Cost :  2905.846599175719
# Simulation run : 8
# Minimum route Cost :  2943.189479262302
# Simulation run : 9
# Minimum route Cost :  2934.0394413913427
#
#
# cooling factor :  0.9
#
#
# Simulation run : 0
# Minimum route Cost :  2849.4392796116213
# Simulation run : 1
# Minimum route Cost :  2883.5503766623106
# Simulation run : 2
# Minimum route Cost :  2677.092074097499
# Simulation run : 3
# Minimum route Cost :  2778.0361974603597
# Simulation run : 4
# Minimum route Cost :  2799.6504221301902
# Simulation run : 5
# Minimum route Cost :  2850.3161978076328
# Simulation run : 6
# Minimum route Cost :  2751.8263211970198
# Simulation run : 7
# Minimum route Cost :  2844.11667920453
# Simulation run : 8
# Minimum route Cost :  2811.0694839851644
# Simulation run : 9
# Minimum route Cost :  2826.1485284165888
#
#
# cooling factor :  0.98
#
#
# Simulation run : 0
# Minimum route Cost :  2670.4479483839505
# Simulation run : 1
# Minimum route Cost :  2700.199337639789
# Simulation run : 2
# Minimum route Cost :  2738.331909229903
# Simulation run : 3
# Minimum route Cost :  2750.2551399520553
# Simulation run : 4
# Minimum route Cost :  2670.531908989054
# Simulation run : 5
# Minimum route Cost :  2688.3971726609925
# Simulation run : 6
# Minimum route Cost :  2696.000704811965
# Simulation run : 7
# Minimum route Cost :  2714.556182399097
# Simulation run : 8
# Minimum route Cost :  2687.504071275218
# Simulation run : 9
# Minimum route Cost :  2729.3402528292704
#
#
# cooling factor :  0.99
#
#
# Simulation run : 0
# Minimum route Cost :  2663.4383886218316
# Simulation run : 1
# Minimum route Cost :  2650.4724693099147
# Simulation run : 2
# Minimum route Cost :  2629.697455410826
# Simulation run : 3
# Minimum route Cost :  2696.59146410905
# Simulation run : 4
# Minimum route Cost :  2693.3440273174187
# Simulation run : 5
# Minimum route Cost :  2670.736020263395
# Simulation run : 6
# Minimum route Cost :  2748.86230973387
# Simulation run : 7
# Minimum route Cost :  2667.0351024627907
# Simulation run : 8
# Minimum route Cost :  2630.494047307239
# Simulation run : 9
# Minimum route Cost :  2660.1464474660775

# %% [markdown]
# ## Shortest Route Cost (Given)

# %%
def read_opt_tsp_file(tsp_file):
    coords = []
    datafile = open(tsp_file,"r")

    while(1):
        line = datafile.readline()
        if "TOUR_SECTION" in line:
            break

    while(1):
        line = datafile.readline()
        if "-1" in line:
            break
        lineList = line.split()

        node = int(lineList[0])
        coords.append(node)
    # Add node-1 at the end to finish the route
    coords.append(1)
    datafile.close()
    return coords

route = read_opt_tsp_file("TSP-Configurations/a280.opt.tour")
#print(route)

from functions import distance_matrix
from functions import read_tsp_file

coords = read_tsp_file("TSP-Configurations/a280.tsp")
dis_matrix = distance_matrix(coords)

num_nodes = len(route)
total_dis = 0
for i in range(num_nodes-1):
    n1 = route[i]
    n2 = route[i+1]
    total_dis += dis_matrix[n1-1][n2-1]

print("Given cost of shortest route: ",total_dis)
# Out:
# Given cost of shortest route:  2586.7696475631606

# %% [markdown]
# ## Data Analysis - Markov chain length - 10,000

# %%
from pandas import read_csv

File_Path = "data/TSP_SA_280data_mk=10000_cf=[0.5,0.99].csv"
df_1 = read_csv(File_Path)
#df_1.head()

# %%
import seaborn as sns


sns.set(rc = {'figure.figsize':(15,8)})

ax = sns.boxplot(x="Cooling Factor", y="Minimal Cost", data=df_1)

# %% [markdown]
# ### Number of steps from T_start to T_end(i.e. number of steps taken to cool down the temperature)

# %%
df_1.head()
df_itr = df_1[["Minimal Cost","iterations"]]
df_itr = df_itr.groupby("iterations")

mean_df_itr = df_itr.mean()
mean_df_itr
# Out:
#             Minimal Cost
# iterations
# 18           3094.133055
# 24           3013.521534
# 35           2964.848827
# 55           2879.978096
# 116          2831.434011
# 605          2706.169135
# 1215         2679.477483

# %% [markdown]
# ## Convergence line graph : Markov chain length = 10,000

# %%
df_line = df_1[["Minimal Cost","Cooling Factor"]]
df_line.head()
# Out:
#    Minimal Cost  Cooling Factor
# 0   3034.438875             0.5
# 1   3090.187536             0.5
# 2   3123.908856             0.5
# 3   3094.539169             0.5
# 4   3075.473661             0.5

# %%
grouped_df = df_line.groupby("Cooling Factor")
#grouped_df.head()

# %%
mean_df = grouped_df.mean()
mean_df
# Out:
#                 Minimal Cost
# Cooling Factor
# 0.50             3094.133055
# 0.60             3013.521534
# 0.70             2964.848827
# 0.80             2879.978096
# 0.90             2831.434011
# 0.98             2706.169135
# 0.99             2679.477483

# %%
sns.lineplot(data=mean_df, x="Minimal Cost",y="Cooling Factor")
# Out:
# <AxesSubplot:xlabel='Minimal Cost', ylabel='Cooling Factor'>

# %% [markdown]
# ## Analysis of acceptance - rejection probability(for T_start to T_end)

# %%
from functions import distance_matrix
from functions import total_dist
from functions import generate_i_j
from functions import two_opt_swap

def comp_shortest_path_accept_reject(T_start, T_end, cooling_factor, nMarkov, coords, dataset, save_data=False):
    """Function that computes the shortest path for the Traveling Salesman Problem using Simulated Annealing.
       It also returns the acceptance probability of a new route from T_start to T_end

        Args:
            T_start (float): Starting temperature
            T_end (float): Temperature that determines when the Anealing process stops
            cooling_factor (float): determines the speed of the cooling process.
            nMarkov (int): Length of the markov chain
            coords (numpy.ndarray): coordinate array with tuples of city coordinates in the form: ()

        Returns:
            tuple: [0] final number of iterations, [1]minimal cost, [2]optimal cities list
    """
    T = T_start
    itr = 0
    matrix = distance_matrix(coords)

    route = np.arange(1,len(coords))
    np.random.shuffle(route)

     # starts and end at the first node in route/
    route = np.append(route,0)
    route = np.append(0,route)

    num_cities = len(route)

    old_cost = total_dist(route,matrix)
    min_cost = old_cost

    best_cost_till_now = []
    new_cost_arr = []

    new_cost = old_cost
    optimal_list_cities = route
    
    acceptance_probability = []
    temperature_range = []

   
    while T >= T_end:
        accepted_routes_T = 0
        for k in range(nMarkov):    # Markov
            i,j = generate_i_j(num_cities)

            new_cost = old_cost - (matrix[route[i-1]][route[i]] + matrix[route[j+1]][route[j]]) + (matrix[route[i-1]][route[j]] + matrix[route[j+1]][route[i]])
            #print(new_cost)

            cost_difference = new_cost - old_cost

            new_cost_arr.append(new_cost)


            if(new_cost < min_cost):
            #print(min_cost)
            #min_cost_arr.append(new_cost)
                min_cost = new_cost
                best_cost_till_now.append(min_cost)

            if(cost_difference < 0):
                prob = 1
            else:
                prob = np.minimum(math.exp(-cost_difference/T),1)

            random_num = np.random.uniform()
            #print(prob)

            # Accept it
            if(random_num <= prob):
                route = two_opt_swap(route,i,j)
                old_cost = new_cost
                optimal_list_cities = route
                accepted_routes_T +=1

        best_cost_till_now.append(min_cost)
        acceptance_probability.append(accepted_routes_T/nMarkov)
        temperature_range.append(T)


        itr = itr + 1
        T = T * cooling_factor
    
    best_cost_till_now_ar = np.asarray(best_cost_till_now)


    return itr, min_cost, optimal_list_cities,best_cost_till_now,acceptance_probability,temperature_range

# %%
T_start = 1000
T_end = 0.005
cooling_factor = 0.8
nMarkov = 10000
num_simulations = 10

coords = read_tsp_file("TSP-Configurations/a280.tsp")
dataset = "a280"



    
itr, min_cost, optimal_list_cities,local_minima_arr,acceptance_probability,temperature_range = comp_shortest_path_accept_reject(T_start, T_end, cooling_factor, nMarkov, coords, dataset=dataset, save_data=False)

# %%
print(acceptance_probability)
print(temperature_range)
# Out:
# [0.9615, 0.955, 0.9359, 0.9202, 0.8976, 0.8792, 0.8389, 0.7998, 0.7691, 0.6934, 0.6385, 0.5518, 0.4779, 0.3951, 0.3293, 0.2521, 0.1666, 0.1297, 0.1012, 0.0683, 0.0499, 0.0303, 0.0251, 0.0192, 0.0142, 0.0104, 0.0078, 0.0054, 0.0039, 0.0035, 0.0033, 0.0018, 0.0013, 0.0013, 0.002, 0.0006, 0.0012, 0.0008, 0.0007, 0.0004, 0.0005, 0.0008, 0.0005, 0.0003, 0.0002, 0.0004, 0.0002, 0.0005, 0.0002, 0.0003, 0.0007, 0.0002, 0.0004, 0.0002, 0.0002]
# [1000, 800.0, 640.0, 512.0, 409.6, 327.68000000000006, 262.14400000000006, 209.71520000000007, 167.77216000000007, 134.21772800000005, 107.37418240000005, 85.89934592000004, 68.71947673600003, 54.97558138880003, 43.980465111040026, 35.18437208883202, 28.14749767106562, 22.517998136852498, 18.014398509482, 14.411518807585601, 11.529215046068481, 9.223372036854785, 7.3786976294838285, 5.902958103587063, 4.722366482869651, 3.777893186295721, 3.022314549036577, 2.4178516392292617, 1.9342813113834094, 1.5474250491067276, 1.237940039285382, 0.9903520314283057, 0.7922816251426447, 0.6338253001141158, 0.5070602400912926, 0.4056481920730341, 0.3245185536584273, 0.25961484292674186, 0.2076918743413935, 0.1661534994731148, 0.13292279957849185, 0.10633823966279349, 0.08507059173023479, 0.06805647338418784, 0.05444517870735027, 0.04355614296588022, 0.03484491437270418, 0.027875931498163344, 0.022300745198530675, 0.01784059615882454, 0.014272476927059633, 0.011417981541647707, 0.009134385233318165, 0.007307508186654533, 0.0058460065493236265]

# %%
import matplotlib.pyplot as plt

xdata = temperature_range
ydata = acceptance_probability

plt.plot(xdata,ydata)
plt.title("Acceptance Probability of a route vs Temperature")
plt.xlabel("Temperature")
plt.ylabel("Acceptance Probability")
plt.show()
